# %% [markdown]
# <a href="https://colab.research.google.com/github/dusky1ight/LocaNavMapie/blob/main/Sem_eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./semeval_train_2022.csv')

# %%
df = df[['tweet','sarcastic']]

# %%
df
# Out:
#                                                   tweet  sarcastic
# 0     The only thing I got from college is a caffein...          1
# 1     I love it when professors draw a big question ...          1
# 2     Remember the hundred emails from companies whe...          1
# 3     Today my pop-pop told me I was not “forced” to...          1
# 4     @VolphanCarol @littlewhitty @mysticalmanatee I...          1
# ...                                                 ...        ...
# 3463  The population spike in Chicago in 9 months is...          0
# 3464  You'd think in the second to last English clas...          0
# 3465  I’m finally surfacing after a holiday to Scotl...          0
# 3466  Couldn't be prouder today. Well done to every ...          0
# 3467  Overheard as my 13 year old games with a frien...          0
#
# [3468 rows x 2 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#                                                   tweet  sarcastic
# 0     The only thing I got from college is a caffein...          1
# 1     I love it when professors draw a big question ...          1
# 2     Remember the hundred emails from companies whe...          1
# 3     Today my pop-pop told me I was not “forced” to...          1
# 4     @VolphanCarol @littlewhitty @mysticalmanatee I...          1
# ...                                                 ...        ...
# 3463  The population spike in Chicago in 9 months is...          0
# 3464  You'd think in the second to last English clas...          0
# 3465  I’m finally surfacing after a holiday to Scotl...          0
# 3466  Couldn't be prouder today. Well done to every ...          0
# 3467  Overheard as my 13 year old games with a frien...          0
#
# [3467 rows x 2 columns]

# %%
pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.3 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 42.0 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 34.1 MB/s
# ...
#      |████████████████████████████████| 61 kB 491 kB/s
# ...
#      |████████████████████████████████| 895 kB 57.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# %%
tokenizer = AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
# Out:
# Downloading:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/851k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/638M [00:00<?, ?B/s]

# %%
tokens = tokenizer.encode('It was good but couldve been better. Great', return_tensors='pt')

# %%
result = model(tokens)
result.logits
# Out:
# tensor([[-2.7768, -1.2353,  1.4419,  1.9804,  0.4584]],
#        grad_fn=<AddmmBackward0>)

# %%
int(torch.argmax(result.logits))
# Out:
# 3

# %%
df['tweet'].iloc[0]
# Out:
# 'The only thing I got from college is a caffeine addiction'

# %%
def sentiment_score(tweet):
    tokens = tokenizer.encode(tweet, return_tensors='pt')
    result = model(tokens)
    return int(torch.argmax(result.logits))+1

# %%
sentiment_score(df['tweet'].iloc[1])
# Out:
# 5

# %%
df['sentiment'] = df['tweet'].apply(lambda x: sentiment_score(x[:512]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                                   tweet  sarcastic  sentiment
# 0     The only thing I got from college is a caffein...          1          1
# 1     I love it when professors draw a big question ...          1          5
# 2     Remember the hundred emails from companies whe...          1          1
# 3     Today my pop-pop told me I was not “forced” to...          1          3
# 4     @VolphanCarol @littlewhitty @mysticalmanatee I...          1          5
# ...                                                 ...        ...        ...
# 3463  The population spike in Chicago in 9 months is...          0          1
# 3464  You'd think in the second to last English clas...          0          2
# 3465  I’m finally surfacing after a holiday to Scotl...          0          5
# 3466  Couldn't be prouder today. Well done to every ...          0          5
# 3467  Overheard as my 13 year old games with a frien...          0          2
#
# [3467 rows x 3 columns]
